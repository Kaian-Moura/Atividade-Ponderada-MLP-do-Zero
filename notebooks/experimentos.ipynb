# %% [markdown]
# # Experimentos e Análises — MLP do Zero
#
# Neste notebook, consolidamos os resultados dos experimentos comparativos que executamos (via script `run_experiments.py`) para analisar o impacto do hiperparâmetro de Taxa de Aprendizado (Learning Rate) no desempenho da nossa rede neural treinada no dataset MNIST.

# %% [markdown]
# ## Comparativo: Loss (Custo)
# O gráfico abaixo exibe a curva da Loss de entropia cruzada nas 30 épocas de treinamento para as duas configurações.

# %%
from IPython.display import Image, display

# Exibindo o Gráfico de Loss
display(Image(filename='../results/loss_comparison.png'))

# %% [markdown]
# ## Comparativo: Acurácia
# O gráfico a seguir exibe a evolução da acurácia tanto nos dados de Treinamento quanto nos dados de Validação/Teste. É possível ver a diferença de velocidade de aprendizado dependendo do passo (learning rate) ajustado no otimizador.

# %%
# Exibindo o Gráfico de Acurácia
display(Image(filename='../results/accuracy_comparison.png'))

# %% [markdown]
# ### Conclusão
# Como podemos observar nos gráficos acima, o **Experimento 1 (LR=0.1)** convergiu muito mais rápido, atingindo altos valores de acurácia já nas primeiras épocas, enquanto o **Experimento 2 (LR=0.01)** precisou de mais tempo para ajustar os pesos na direção do gradiente, concluindo na 30ª época com uma acurácia inferior (97.42% contra 97.94%). Ambas as curvas se mostraram estáveis (sem divergências grotescas da loss), o que indica que a *He Initialization* dos pesos foi perfeitamente executada e o *vanishing/exploding gradient* foi contornado.
